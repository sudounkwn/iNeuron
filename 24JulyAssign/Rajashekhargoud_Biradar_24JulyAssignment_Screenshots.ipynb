# %% [markdown]
# #1  Attribute DataSet table creation and data insertion into it
#
#
# ![AttributeDataSet_Table.png](attachment:AttributeDataSet_Table.png)

# %% [markdown]
# #2 Dress Sales table creation and data insertion into it
#
# ![DressSales_Table.png](attachment:DressSales_Table.png)

# %% [markdown]
# #3 MongoDB data insert as JSON
#
# ![MongoDB_dataInsert.png](attachment:MongoDB_dataInsert.png)
